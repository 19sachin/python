# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.iplt20.com/matches/points-table'

# %%
page = requests.get(url)

print(page.status_code)      # Check if the request was successful (200 = OK)
# Out:
# 200

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title data-page-title="IPL 2025 Points Table | Team Standings and Rankings | IPLT20" id="page_title">IPL 2025 Points Table | Team Standings and Rankings | IPLT20</title>
# <link href="https://www.iplt20.com/matches/points-table" rel="canonical"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0" name="viewport"/>
# <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no"> -->
# <meta content="q5qEN5mh5Dl7Bd8Dy1w982CKy8LW7jyg2I1LkdAa" name="csrf-token"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="#19398a" name="theme-color"/>
# <meta content="website" name="og:type"/>
# <meta content="https://www.iplt20.com/matches/points-table" name="og:url"/>
# ...
